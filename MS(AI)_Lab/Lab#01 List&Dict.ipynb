# %% [markdown]
# # **Lab Task#01**
# Write a Python code for the following scenario:
#
# Suppose an instructor of a class wants to maintain record of his students in a python dictionary data structure. The designed system asks the instructor for a record of each student one by one as a console input and passes it through a set of sequential steps before generating a dictionary data structure.
#
# Write a Python script to perform following set of operations to generate dictionary of data for students.
#
# 1. The script should ask the instructor repeatedly for a “student ID”, “name” and his “residential city name” and store it in three different lists. If the instructor types “stop” the loop should exit.
#
# 2. Traverse the three lists generated in “part 1” and create a dictionary data structure out of it. The script should take ID of student as a Key of the dictionary and rest of the attributes as a list within that dictionary in following sequence: {1:[“name”,”city”]}
#
# Once dictionary is created, the instructor should be able to query the data. He should provide ID of the student as a console input and script should return the name and city of the student.

# %% [markdown]
# # New Section

# %%
student_record = []  # Empty List for student records
student = {}  # Empty Dictionary for student records

student_id = []
student_Name = []
student_City = []

while True:
    id_val = input("Enter ID: ")
    student_record.append(id_val)
    student_id.append(id_val)

    name_val = input("Enter Name: ")
    student_record.append(name_val)
    student_Name.append(name_val)

    city_val = input("Enter City:")
    student_record.append(city_val)
    student_City.append(city_val)
#Ask for more student record
    Add = input("Want to add more student record (yes/no): ")
    if Add != 'yes':
        break

#Convert lists into a dictionary
student_dict = {student_id[i]: [student_Name[i], student_City[i]] for i in range(len(student_id))}
print("\nStudent Dictionary:", student_dict)

#Search student data
while True:
    search_id = input("\nEnter Student ID to search or type 'exit' to stop): ")
    if search_id == "exit":
        break

    if search_id in student_dict:
        print(f"Student Name: {student_dict[search_id][0]}, City: {student_dict[search_id][1]}")
    else:
        print("Student ID not found")
# Out:
# Enter ID: 1
# Enter Name: abc
# Enter City:xyz
# Want to add more student record (yes/no): no
#
# Student Dictionary: {'1': ['abc', 'xyz']}
#
# Enter Student ID to search or type 'exit' to stop): 1
# Student Name: abc, City: xyz
#
# Enter Student ID to search or type 'exit' to stop): exit
